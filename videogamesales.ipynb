# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("vgsales.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
missing_values_count = df.isnull().sum() 
missing_values_count
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Out:
# True

# %%
X=df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
Y=df['Global_Sales']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
det_tree=DecisionTreeClassifier(criterion='entropy',max_depth=7,random_state=0)

# %%
det_tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=0)

# %%
pred_val_y=det_tree.predict(X_test)

# %%
print(y.sum(),"\n") 
print(pred_val_y.sum())
# Out:
# SportsPlatformRacingSportsRole-PlayingPuzzlePlatformMiscPlatformShooterSimulationRacingRole-PlayingSportsSportsMiscActionActionPlatformMiscRole-PlayingPlatformPlatformActionActionRole-PlayingRole-PlayingPuzzleRacingShooterRole-PlayingShooterRole-PlayingShooterShooterShooterShooterShooterActionFightingShooterSimulationRacingShooterActionActionPlatformRacingPlatformRole-PlayingAdventureActionRacingPlatformRacingShooterActionPlatformRole-PlayingPlatformMiscShooterShooterRacingPlatformShooterRole-PlayingShooterMiscRacingShooterPlatformMiscSimulationMiscRole-PlayingRacingSportsMiscShooterMiscRole-PlayingActionSimulationShooterSportsRole-PlayingRole-PlayingRole-PlayingPuzzleActionPlatformShooterShooterActionPlatformPlatformFightingShooterShooterActionShooterMiscShooterRacingFightingPlatformFightingRacingRole-PlayingRacingMiscSportsRacingShooterActionPlatformSportsShooterActionShooterSportsMiscActionSportsPlatformRole-PlayingActionActionShooterRole-PlayingRole-PlayingRole-PlayingShooterActionPlatformFightingRole-PlayingActionSportsShooterShooterActionPlatformActionActionActionRole-PlayingPlatformRole-PlayingActionActionFightingSimulationShooterPuzzleActionFightingAdventureActionRacingRole-PlayingPlatformRacingPlatformStrategyShooterPlatformMiscRole-PlayingPuzzleMiscActionRole-PlayingRole-PlayingPlatformActionPuzzleActionSportsRole-PlayingRole-PlayingPlatformPlatformPlatformActionActionPlatformSimulationSportsShooterPlatformRole-PlayingShooterSimulationMiscActionActionActionSportsPlatformActionSportsFightingStrategyPlatformShooterMiscRole-PlayingRole-PlayingActionSportsActionRacingRole-PlayingPuzzleActionStrategyAdventureSportsRacingSportsActionActionRacingSportsSimulationActionRacingActionMiscActionActionSportsActionShooterActionMiscSportsPlatformSportsActionRole-PlayingActionShooterActionMiscMiscSportsSportsRole-PlayingAdventureRacingShooterPlatformRole-PlayingSportsShooterShooterRole-PlayingShooterPlatformActionActionMiscActionPlatformStrategyActionSportsMiscShooterRacingActionFightingSportsActionRacingActionSportsActionShooterPlatformSportsActionFightingMiscRole-PlayingRole-PlayingRole-PlayingActionRacingSportsMiscFightingShooterShooterMiscSportsRole-PlayingPuzzleShooterMiscSportsActionPlatformSportsActionRole-PlayingRacingRole-PlayingFightingRole-PlayingSportsSportsSportsMiscMiscActionRole-PlayingMiscSimulationActionSportsActionActionPlatformMiscSimulationPlatformActionRole--PlayingShooterFightingShooterPlatformActionRole-Playing